# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %pip install seaborn

# %%
import seaborn as sb

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("USA_Housing (1).csv")
data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
data.shape
# Out:
# (5000, 7)

# %%
data.ndim
# Out:
# 2

# %%
for i in data.columns:
    print(i)
# Out:
# Avg. Area Income
# Avg. Area House Age
# Avg. Area Number of Rooms
# Avg. Area Number of Bedrooms
# Area Population
# Price
# Address

# %%
data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
data.tail()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 254.0+ KB

# %%
data.describe().transpose()
# Out:
#                                count          mean            std  \
# Avg. Area Income              5000.0  6.858311e+04   10657.991214
# Avg. Area House Age           5000.0  5.977222e+00       0.991456
# Avg. Area Number of Rooms     5000.0  6.987792e+00       1.005833
# Avg. Area Number of Bedrooms  5000.0  3.981330e+00       1.234137
# Area Population               5000.0  3.616352e+04    9925.650114
# Price                         5000.0  1.232073e+06  353117.626581
#
#                                        min            25%           50%  \
# Avg. Area Income              17796.631190   61480.562388  6.880429e+04
# Avg. Area House Age               2.644304       5.322283  5.970429e+00
# Avg. Area Number of Rooms         3.236194       6.299250  7.002902e+00
# Avg. Area Number of Bedrooms      2.000000       3.140000  4.050000e+00
# Area Population                 172.610686   29403.928702  3.619941e+04
# ...

# %%
data.describe(include='object')
# Out:
#                                                   Address
# count                                                5000
# unique                                               5000
# top     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# freq                                                    1

# %%
data.nunique()
# Out:
# Avg. Area Income                5000
# Avg. Area House Age             5000
# Avg. Area Number of Rooms       5000
# Avg. Area Number of Bedrooms     255
# Area Population                 5000
# Price                           5000
# Address                         5000
# dtype: int64

# %%
data['Address'].value_counts()
# Out:
# 208 Michael Ferry Apt. 674\nLaurabury, NE 37010-5101             1
# 314 Christopher Square Apt. 404\nLake Ronaldville, SD 42025      1
# 21042 Wilson Islands Suite 238\nFischerchester, MP 42425-4129    1
# Unit 8831 Box 5748\nDPO AE 73012-7314                            1
# 481 Kaitlin Mission Apt. 309\nJodystad, IA 16947                 1
#                                                                 ..
# 054 Carter Crescent Suite 674\nGlennport, WA 11140               1
# 8460 Kathleen Mission Apt. 482\nPort Amytown, KY 72016           1
# 3737 Hartman Rue\nReneestad, ID 69250-7718                       1
# 3465 Latoya Well\nNelsonmouth, MI 55741-4287                     1
# 37778 George Ridges Apt. 509\nEast Holly, NV 29290-3595          1
# Name: Address, Length: 5000, dtype: int64

# %%
data.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
data.Price.unique()
# Out:
# array([1059033.55787012, 1505890.91484695, 1058987.98787608, ...,
#        1030729.58315229, 1198656.87240769, 1298950.48026696])

# %%
numdata=data.select_dtypes(include=np.number).columns
for j in numdata:
    print(data[j].value_counts())
    print()
    print('.........................................')
# Out:
# 79545.458574    1
# 68735.436608    1
# 71635.473101    1
# 73211.136245    1
# 86249.993070    1
#                ..
# 66064.532823    1
# 59390.346824    1
# 64661.930276    1
# 73279.030904    1
# 65510.581804    1
# Name: Avg. Area Income, Length: 5000, dtype: int64
#
# .........................................
# 5.682861    1
# 7.721909    1
# 5.866996    1
# 6.501139    1
# 6.155403    1
#            ..
# 6.659562    1
# 5.664971    1
# 4.656696    1
# 5.902296    1
# 5.992305    1
# Name: Avg. Area House Age, Length: 5000, dtype: int64
#
# .........................................
# 7.009188     1
# 7.621975     1
# 6.075987     1
# 10.280022    1
# 7.967184     1
#             ..
# 6.881398     1
# 6.750872     1
# 5.660253     1
# 8.077578     1
# 6.792336     1
# Name: Avg. Area Number of Rooms, Length: 5000, dtype: int64
#
# .........................................
# 4.38    46
# 3.17    41
# 3.40    40
# 3.16    39
# 3.22    38
#         ..
# 6.31     7
# 6.01     6
# ...

# %%
catdata=data.select_dtypes(include='object').columns
for j in catdata:
    print(data[j].value_counts())
    print()
    print('....................................')
# Out:
# 208 Michael Ferry Apt. 674\nLaurabury, NE 37010-5101             1
# 314 Christopher Square Apt. 404\nLake Ronaldville, SD 42025      1
# 21042 Wilson Islands Suite 238\nFischerchester, MP 42425-4129    1
# Unit 8831 Box 5748\nDPO AE 73012-7314                            1
# 481 Kaitlin Mission Apt. 309\nJodystad, IA 16947                 1
#                                                                 ..
# 054 Carter Crescent Suite 674\nGlennport, WA 11140               1
# 8460 Kathleen Mission Apt. 482\nPort Amytown, KY 72016           1
# 3737 Hartman Rue\nReneestad, ID 69250-7718                       1
# 3465 Latoya Well\nNelsonmouth, MI 55741-4287                     1
# 37778 George Ridges Apt. 509\nEast Holly, NV 29290-3595          1
# Name: Address, Length: 5000, dtype: int64
#
# ....................................

# %%
categorical_data = data.select_dtypes(include='object').columns
for col in categorical_data:
 sb.countplot(data=data, x=col)
 plt.show()

# %%
def attribute_info(df_feature):
  print('Description of features:' '/n')
  print(df_feature.describe(),'/n')

  print('Value_counts:' '/n')
  print(df_feature.value_counts(),'/n')

  print('Unique values:' '/n')
  print(df_feature.unique(),'/n')

  print('Missing values:' '/n')
  print(df_feature.sum(),'/n')

# %%
for col in data:
 print('\033[1m' + 'Attribute Name: ', col + '\033[0m')
 print()
 attribute_info(data[col])
 print('----------------------------------------------------------------------')
# Out:
# Attribute Name:  Avg. Area Income
#
# Description of features:/n
# count      5000.000000
# mean      68583.108984
# std       10657.991214
# min       17796.631190
# 25%       61480.562388
# 50%       68804.286404
# 75%       75783.338666
# max      107701.748378
# Name: Avg. Area Income, dtype: float64 /n
# Value_counts:/n
# 79545.458574    1
# 68735.436608    1
# 71635.473101    1
# 73211.136245    1
# 86249.993070    1
#                ..
# 66064.532823    1
# 59390.346824    1
# 64661.930276    1
# 73279.030904    1
# 65510.581804    1
# Name: Avg. Area Income, Length: 5000, dtype: int64 /n
# Unique values:/n
# [79545.45857432 79248.64245483 61287.06717866 ... 63390.6868855
#  68001.33123509 65510.58180367] /n
# Missing values:/n
# 342915544.91979873 /n
# ----------------------------------------------------------------------
# Attribute Name:  Avg. Area House Age
#
# Description of features:/n
# count    5000.000000
# mean        5.977222
# std         0.991456
# ...

# %%
data.hist(figsize=(15,10), bins=10)
plt.show()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
sb.boxplot(data)
plt.show()

# %%
sb.boxplot(data['Avg. Area Income'])
plt.show()

# %%
data[data['Avg. Area Income'] < 41000]
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 12        39033.809237             7.671755                   7.250029
# 214       40503.541332             6.881779                   6.566175
# 263       40366.616291             4.902940                   7.617118
# 844       39411.652788             4.385845                   7.047435
# 1357      40185.733891             5.949763                   5.753579
# 1597      39294.036523             5.928585                   5.960676
# 1606      40752.714243             5.507106                   6.503331
# 1987      40394.039129             5.132973                   7.600035
# 2915      40581.778087             4.169820                   7.415416
# 3077      40141.566477             5.055820                   7.398154
# 3141      40748.653087             6.250398                   5.586794
# 4449      39777.606906             5.804627                   7.147719
# ...

# %%
data[data['Avg. Area Income'] < 41000].index
# Out:
# Int64Index([12, 214, 263, 844, 1357, 1597, 1606, 1987, 2915, 3077, 3141, 4449,
#             4744],
#            dtype='int64')

# %%
data.drop(index=[12, 214, 263, 844, 1357, 1597, 1606, 1987, 2915, 3077, 3141, 4449,
            4744], axis=0, inplace=True)

# %%
sb.boxplot(data['Avg. Area Income'])
plt.show()

# %%
data[data['Avg. Area Income'] > 97000]
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 428       97112.361252             5.914725                   6.133646
# 558       99629.013581             5.431863                   7.351398
# 693      107701.748378             7.143522                   8.518608
# 962      101928.858060             4.829586                   9.039382
# 1096      97548.310413             5.460973                   6.609396
# 1734     104702.724257             5.575523                   6.932106
# 1891     101144.323930             6.350845                   7.231771
# 2300      98468.253641             7.035383                   6.629233
# 2719     101599.670580             7.798746                   7.480512
# 3483      97881.587279             5.034395                   7.575905
# 3541     102881.120902             6.471249                   5.693536
# 3798      97669.064491             6.888763                   6.739379
# ...

# %%
data[data['Avg. Area Income'] > 97000].index
# Out:
# Int64Index([ 428,  558,  693,  962, 1096, 1734, 1891, 2300, 2719, 3483, 3541,
#             3798, 3947, 4087, 4400],
#            dtype='int64')

# %%
data.drop(index=[428,  558,  693,  962, 1096, 1734, 1891, 2300, 2719, 3483, 3541,
            3798, 3947, 4087, 4400], axis=0, inplace=True)

# %%
sb.boxplot(data['Avg. Area Income'])
plt.show()

# %%
data.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
df = data[['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
       'Avg. Area Number of Bedrooms', 'Area Population', 'Price']]
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
df.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.008531
# Avg. Area House Age                  -0.008531             1.000000
# Avg. Area Number of Rooms            -0.013711            -0.008348
# Avg. Area Number of Bedrooms          0.018740             0.005824
# Area Population                      -0.009690            -0.018592
# Price                                 0.626982             0.455486
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.013711
# Avg. Area House Age                           -0.008348
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.463040
# Area Population                                0.004615
# Price                                          0.341054
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %%
sb.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
data.corr()['Price']
# Out:
# Avg. Area Income                0.626982
# Avg. Area House Age             0.455486
# Avg. Area Number of Rooms       0.341054
# Avg. Area Number of Bedrooms    0.173021
# Area Population                 0.417506
# Price                           1.000000
# Name: Price, dtype: float64

# %%
data.drop(['Address'],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price'],
#       dtype='object')

# %%
X = data.iloc[:,0:-1]
X
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09     23086.800503
# ...

# %%
y = data['Price']
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 4958, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4340      73659.103453             4.662017                   5.080215
# 4386      73470.933162             5.722509                   6.169215
# 169       62784.332948             7.572350                   4.652718
# 4339      66262.192525             6.292294                   4.923681
# 853       74633.941705             5.745854                   5.627388
# ...                ...                  ...                        ...
# 4973      78743.759274             6.583685                   6.595683
# 3295      54649.236026             5.763118                   7.867808
# 1669      78241.075381             5.642007                   8.983474
# 2631      70965.067652             4.999277                   7.459939
# 2757      59611.332368             5.522891                   7.396698
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
X_test
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 942       86611.178018             4.849507                   8.303302
# 3724      45557.523931             5.572561                   8.010397
# 2755      66447.483222             4.376754                   8.422240
# 144       47681.361733             6.890508                   7.788268
# 3325      65022.825804             5.212407                   8.026912
# ...                ...                  ...                        ...
# 3695      72515.915532             5.846975                   8.151894
# 3055      92774.675688             5.990649                   7.163241
# 1231      73438.587066             6.448721                   6.293757
# 1075      76855.865791             4.740996                   6.091631
# 31        68652.609211             6.124342                   6.290820
#
#       Avg. Area Number of Bedrooms  Area Population
# 942                           3.01     45359.027954
# ...

# %%
X.shape
# Out:
# (4958, 5)

# %%
y_train
# Out:
# 4340    6.517880e+05
# 4386    1.144901e+06
# 169     1.007479e+06
# 4339    1.199128e+06
# 853     1.056977e+06
#             ...
# 4973    1.340770e+06
# 3295    1.048136e+06
# 1669    1.160146e+06
# 2631    8.563835e+05
# 2757    1.040782e+06
# Name: Price, Length: 3966, dtype: float64

# %%
y_test
# Out:
# 942     1.668671e+06
# 3724    6.150557e+05
# 2755    1.271397e+06
# 144     1.230149e+06
# 3325    1.004041e+06
#             ...
# 3695    1.290784e+06
# 3055    1.883469e+06
# 1231    1.212462e+06
# 1075    1.240320e+06
# 31      1.170721e+06
# Name: Price, Length: 992, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = lr.predict(X_train)
y_test_pred = lr.predict(X_test)

# %%
y_train
# Out:
# 4340    6.517880e+05
# 4386    1.144901e+06
# 169     1.007479e+06
# 4339    1.199128e+06
# 853     1.056977e+06
#             ...
# 4973    1.340770e+06
# 3295    1.048136e+06
# 1669    1.160146e+06
# 2631    8.563835e+05
# 2757    1.040782e+06
# Name: Price, Length: 3966, dtype: float64

# %%
len(y_train_pred)
# Out:
# 3966

# %%
y_train_pred
# Out:
# array([ 945043.91174877, 1146031.39233912, 1069302.49683907, ...,
#        1393790.85984731,  867227.45795233, 1076459.38152115])

# %%
y_test
# Out:
# 942     1.668671e+06
# 3724    6.150557e+05
# 2755    1.271397e+06
# 144     1.230149e+06
# 3325    1.004041e+06
#             ...
# 3695    1.290784e+06
# 3055    1.883469e+06
# 1231    1.212462e+06
# 1075    1.240320e+06
# 31      1.170721e+06
# Name: Price, Length: 992, dtype: float64

# %%
y_test_pred
# Out:
# array([1668670.6558121 ,  615055.67579218, 1271396.51800598,
#        1230149.13678644, 1004041.43483931, 1441576.84676066,
#        1209445.22037353, 1196687.68676655,  706135.14463891,
#        1445731.62594336, 1459834.78943576, 1523915.14468417,
#         542596.98952502, 1084763.02966111, 1026126.58382677,
#        1529281.84011934, 1232466.39976016,  987973.89278788,
#        1245749.59438337,  880851.0551992 , 1260826.63799718,
#         897479.95016906, 1869886.3052624 , 1483685.90380273,
#        1336172.19406627,  565732.81754028, 1609581.80429773,
#        1717570.52990384, 1029273.27859557, 1654965.29571208,
#        1852375.50677484,  802846.12229537, 1194594.98836649,
#        1103352.60093982, 1394132.24138655, 1599634.46503679,
#        1448995.11464484, 1530294.57733993, 1110114.22034477,
#        1726719.06674413, 1279681.15439659, 1232004.82983475,
#        1420979.18428571, 1520371.00751546,  691941.39658855,
# ...

# %%
lr.coef_
# Out:
# array([2.16898153e+01, 1.65137701e+05, 1.21837607e+05, 6.20766451e+02,
#        1.51965186e+01])

# %%
coeff_df = pd.DataFrame(lr.coef_, X.columns, columns=['Coefficients'])
coeff_df
# Out:
#                                Coefficients
# Avg. Area Income                  21.689815
# Avg. Area House Age           165137.701500
# Avg. Area Number of Rooms     121837.607224
# Avg. Area Number of Bedrooms     620.766451
# Area Population                   15.196519

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_train, y_train_pred)

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_train, y_train_pred, color='m', label='Actual Price')
plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], 'k--', lw=4, label='Predicted Price')
plt.title('Best fit line on Training Data')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(y_test, y_test_pred)

# %%
#For Training Data
plt.figure(figsize=(10,6))
plt.scatter(y_test, y_test_pred, color='c', label='Actual Price')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4, label='Predicted Price')
plt.title('Best fit line on Test Data')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mean_squared_error(y_train, y_train_pred)
# Out:
# 10126172551.504168

# %%
mean_squared_error(y_train, y_train_pred)
# Out:
# 10126172551.504168

# %%
r2_score(y_train, y_train_pred)
# Out:
# 0.9161919277601694

# %%
def training_evaluation(actual, predicted):

 mse = mean_squared_error(actual, predicted)
 rmse = np.sqrt(mean_squared_error(actual, predicted))
 mae = mean_absolute_error(actual, predicted)
 r2 = r2_score(actual, predicted)


 print(f'MSE: {mse}')
 print(f'RMSE: {rmse}')
 print(f'MAE: {mae}')
 print(f'R2_Score: {r2}')

# %%
print('Training Set Evaluation: ', '\n----------------------------------')
training_evaluation(y_train, y_train_pred)
# Out:
# Training Set Evaluation:
# ----------------------------------
# MSE: 10126172551.504168
# RMSE: 100628.88527408105
# MAE: 81165.9260424149
# R2_Score: 0.9161919277601694

# %%
print('Training Set Evaluation: ', '\n----------------------------------')
training_evaluation(y_train, y_train_pred)
# Out:
# Training Set Evaluation:
# ----------------------------------
# MSE: 10126172551.504168
# RMSE: 100628.88527408105
# MAE: 81165.9260424149
# R2_Score: 0.9161919277601694
